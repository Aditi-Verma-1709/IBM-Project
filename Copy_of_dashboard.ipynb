# %%
 pip install pandas dash
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import required libraries
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
import plotly.express as px

# %%
# Read the airline data into pandas dataframe
spacex_df = pd.read_csv("spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application
app = dash.Dash(__name__)

# Create an app layout
app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 40}),
                                # TASK 1: Add a dropdown list to enable Launch Site selection
                                # The default select value is for ALL sites
                                dcc.Dropdown(id='site-dropdown',
                                             options=[{'label':'All Sites','value':'ALL'},
                                                      {'label':'CCAFS LC-40','value':'CCAFS LC-40'},
                                                      {'label':'CCAFS SLC-40','value':'CCAFS SLC-40'},
                                                      {'label':'KSC LC-39A','value':'KSC LC-39A'},
                                                      {'label':'AFB SLC-4E','value':'AFB SLC-4E'}
                                                     ],
                                            value='ALL',
                                            placeholder="Select a Launch Site here",
                                            searchable=True
                                            ),
                                html.Br(),

                                # TASK 2: Add a pie chart to show the total successful launches count for all sites
                                # If a specific launch site was selected, show the Success vs. Failed counts for the site
                                html.Div(dcc.Graph(id='success-pie-chart')),
                                html.Br(),

                                html.P("Payload range (Kg):"),
                                # TASK 3: Add a slider to select payload range
                                dcc.RangeSlider(id='payload-slider',
                                                min=0, max=10000, step=1000,
                                                marks={0: '0',2500: '2500',
                                                       5000: '5000',
                                                       7500: '7500',
                                                       10000: '10000'},
                                                value=[min_payload,max_payload]),

                                # TASK 4: Add a scatter chart to show the correlation between payload and launch success
                                html.Div(dcc.Graph(id='success-payload-scatter-chart')),
                                ])

# TASK 2:
# Add a callback function for `site-dropdown` as input, `success-pie-chart` as output
@app.callback(Output(component_id='success-pie-chart',component_property='figure'),
              Input(component_id='site-dropdown',component_property='value'))
def get_pie_chart(entered_site):
    if entered_site=='ALL':
        fig = px.pie(spacex_df, values='class', 
                     names='Launch Site',
                     title='Total success launches by sites')
        fig.update_layout()
        return fig
    elif entered_site=='CCAFS LC-40':
        filtered_df=spacex_df[spacex_df['Launch Site']=='CCAFS LC-40']

        fig = px.pie(filtered_df,names='class',
                     title='Total success launches by site '+str(entered_site))
        fig.update_layout()
        return fig
    elif entered_site=='CCAFS SLC-40':
        filtered_df=spacex_df[spacex_df['Launch Site']=='CCAFS SLC-40']
        fig = px.pie(filtered_df,names='class',
                     title='Total success launches by site '+str(entered_site))
        fig.update_layout()
        return fig
    elif entered_site=='KSC LC-39A':
        filtered_df=spacex_df[spacex_df['Launch Site']=='KSC LC-39A']
        fig = px.pie(filtered_df,names='class',
                     title='Total success launches by site '+str(entered_site))
        fig.update_layout()
        return fig
    elif entered_site=='VAFB SLC-4E':
        filtered_df=spacex_df[spacex_df['Launch Site']=='VAFB SLC-4E']
        fig = px.pie(filtered_df,names='class',
                     title='Total success launches by site '+str(entered_site))
        fig.update_layout()
        return fig

# TASK 4:
# Add a callback function for `site-dropdown` and `payload-slider` as inputs, `success-payload-scatter-chart` as output
@app.callback(Output(component_id='success-payload-scatter-chart', component_property='figure'),
              Input(component_id='site-dropdown', component_property='value'),
              Input(component_id="payload-slider", component_property='value'))

def update_scatter_chart(entered_site,payload_of_satellite):
    low, high=payload_of_satellite
    a=(spacex_df['Payload Mass (kg)']>low) & (spacex_df['Payload Mass (kg)']<high)
    filtered_df=spacex_df[a]
    if entered_site=='ALL':
        fig=px.scatter(filtered_df,x='Payload Mass (kg)',y='class',color="Booster Version Category",
                       title='Correlation between Payload and Success for all Sites')
        fig.update_layout()
        return fig
    elif entered_site=='CCAFS LC-40':
         filtered_df1=filtered_df[filtered_df['Launch Site']=='CCAFS LC-40']
         fig=px.scatter(filtered_df1,x='Payload Mass (kg)',y='class',color="Booster Version Category",
                        title='Correlation between Payload and Success for site '+str(entered_site))
         fig.update_layout()
         return fig
    elif entered_site=='CCAFS SLC-40':
         filtered_df1=filtered_df[filtered_df['Launch Site']=='CCAFS SLC-40']
         fig=px.scatter(filtered_df1,x='Payload Mass (kg)',y='class',color="Booster Version Category",
                        title='Correlation between Payload and Success for site '+str(entered_site))
         fig.update_layout()
         return fig
    elif entered_site=='KSC LC-39A':
         filtered_df1=filtered_df[filtered_df['Launch Site']=='KSC LC-39A']
         fig=px.scatter(filtered_df1,x='Payload Mass (kg)',y='class',color="Booster Version Category",
                        title='Correlation between Payload and Success for site '+str(entered_site))
         fig.update_layout()
         return fig
    elif entered_site=='VAFB SLC-4E':
         filtered_df1=filtered_df[filtered_df['Launch Site']=='VAFB SLC-4E']
         fig=px.scatter(filtered_df1,x='Payload Mass (kg)',y='class',color="Booster Version Category",
                        title='Correlation between Payload and Success for site '+str(entered_site))
         fig.update_layout()
         return fig
# Run the app
if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [23/Mar/2023 00:21:46] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Mar/2023 00:21:46] "GET /_dash-component-suites/dash/deps/polyfill@7.v2_8_1m1678916811.12.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Mar/2023 00:21:46] "GET /_dash-component-suites/dash/deps/react@16.v2_8_1m1678916811.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Mar/2023 00:21:46] "GET /_dash-component-suites/dash/deps/react-dom@16.v2_8_1m1678916811.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Mar/2023 00:21:46] "GET /_dash-component-suites/dash/deps/prop-types@15.v2_8_1m1678916811.8.1.min.js HTTP/1.1" 200 -
# ...

# %%
python3.8 spacex_dash_app.py
